# %%
import pandas as pd
pd.read_csv('data.csv',sep=',')
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
pd.read_csv('data.csv',sep='#')
# Out:
#     Duration,Pulse,Maxpulse,Calories
# 0                   60,110,130,409.1
# 1                   60,117,145,479.0
# 2                   60,103,135,340.0
# 3                   45,109,175,282.4
# 4                   45,117,148,406.0
# ..                               ...
# 164                 60,105,140,290.8
# 165                 60,110,145,300.0
# 166                 60,115,145,310.2
# 167                 75,120,150,320.4
# 168                 75,125,150,330.4
#
# [169 rows x 1 columns]

# %%
pd.read_csv('data.csv',na_values='60')
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0         NaN    110       130     409.1
# 1         NaN    117       145     479.0
# 2         NaN    103       135     340.0
# 3        45.0    109       175     282.4
# 4        45.0    117       148     406.0
# ..        ...    ...       ...       ...
# 164       NaN    105       140     290.8
# 165       NaN    110       145     300.0
# 166       NaN    115       145     310.2
# 167      75.0    120       150     320.4
# 168      75.0    125       150     330.4
#
# [169 rows x 4 columns]

# %%
pd.read_csv('data.csv',index_col=['Pulse'])
# Out:
#        Duration  Maxpulse  Calories
# Pulse
# 110          60       130     409.1
# 117          60       145     479.0
# 103          60       135     340.0
# 109          45       175     282.4
# 117          45       148     406.0
# ...         ...       ...       ...
# 105          60       140     290.8
# 110          60       145     300.0
# 115          60       145     310.2
# 120          75       150     320.4
# 125          75       150     330.4
#
# [169 rows x 3 columns]

# %%
pd.read_csv('data.csv',header=None)
# Out:
#             0      1         2         3
# 0    Duration  Pulse  Maxpulse  Calories
# 1          60    110       130     409.1
# 2          60    117       145     479.0
# 3          60    103       135     340.0
# 4          45    109       175     282.4
# ..        ...    ...       ...       ...
# 165        60    105       140     290.8
# 166        60    110       145     300.0
# 167        60    115       145     310.2
# 168        75    120       150     320.4
# 169        75    125       150     330.4
#
# [170 rows x 4 columns]

# %%
pd.read_csv('data.csv',nrows=3)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0

# %%
pd.read_csv('data.csv',skiprows=3)
# Out:
#      60  103  135  340.0
# 0    45  109  175  282.4
# 1    45  117  148  406.0
# 2    60  102  127  300.0
# 3    60  110  136  374.0
# 4    45  104  134  253.3
# ..   ..  ...  ...    ...
# 161  60  105  140  290.8
# 162  60  110  145  300.0
# 163  60  115  145  310.2
# 164  75  120  150  320.4
# 165  75  125  150  330.4
#
# [166 rows x 4 columns]

# %%
df=pd.read_csv('data.csv',sep=',')
df.set_index('Duration')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df .info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df[['Duration', 'Pulse']].head()
df.loc[[2,3]]
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 2        60    103       135     340.0
# 3        45    109       175     282.4

# %%
df.loc[[2,3],['Duration', 'Pulse'] ]
# Out:
#    Duration  Pulse
# 2        60    103
# 3        45    109

# %%
df.iloc[1]
# Out:
# Duration     60.0
# Pulse       117.0
# Maxpulse    145.0
# Calories    479.0
# Name: 1, dtype: float64

# %%
df.iloc[:1,:5]
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1

# %%
df['new']=df['remo']*df['salary']
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.drop([1],axis=0)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [168 rows x 4 columns]

# %%
df['Duration'].unique()
# Out:
# array([ 60,  45,  30,  80,  20, 210, 160, 180, 150, 300,  90, 120, 270,
#         15,  25,  75])

# %%
df['Duration'].nunique()
# Out:
# 16

# %%
df['Duration'].value_counts()
# Out:
# Duration
# 60     79
# 45     35
# 30     16
# 20      9
# 90      8
# 150     4
# 180     3
# 120     3
# 210     2
# 160     2
# 15      2
# 75      2
# 80      1
# 300     1
# 270     1
# 25      1
# Name: count, dtype: int64

# %%
df['Duration'].value_counts().sort_values()
# Out:
# Duration
# 80      1
# 300     1
# 270     1
# 25      1
# 210     2
# 160     2
# 15      2
# 75      2
# 120     3
# 180     3
# 150     4
# 90      8
# 20      9
# 30     16
# 45     35
# 60     79
# Name: count, dtype: int64

# %%
pd.crosstab(df["Pulse"],df["Calories"], normalize="index")
# Out:
# Calories  50.3    50.5      77.7      86.2      92.7      100.7     105.3   \
# Pulse
# 80           0.0     0.5  0.000000  0.000000  0.000000  0.000000  0.000000
# 83           1.0     0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 85           0.0     0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 90           0.0     0.0  0.000000  0.090909  0.000000  0.000000  0.090909
# 92           0.0     0.0  0.000000  0.000000  0.333333  0.000000  0.000000
# 93           0.0     0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 95           0.0     0.0  0.333333  0.000000  0.000000  0.000000  0.000000
# 97           0.0     0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 98           0.0     0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 99           0.0     0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 100          0.0     0.0  0.000000  0.000000  0.000000  0.052632  0.000000
# ...

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df[df['Pulse']>110]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 1          60    117       145     479.0
# 4          45    117       148     406.0
# 22         60    130       101     300.0
# 35         60    114       140     415.0
# 43         60    111       138     400.0
# 44         60    111       131     397.0
# 47         45    111       136     300.0
# 49         60    111       139     397.6
# 51         80    123       146     643.1
# 53         60    118       151     486.0
# 54         30    136       175     238.0
# 55         60    121       146     450.7
# 56         60    118       121     413.0
# 57         45    115       144     305.0
# 58         20    153       172     226.4
# 59         45    123       152     321.0
# 63         45    118       141     341.0
# 74         45    114       146     304.0
# 80         30    159       182     319.2
# 81         45    149       169     344.0
# 85         30    151       170     300.0
# 88         45    129       103     242.0
# ...

# %%
df.isna().sum().sort_values().head(7)
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df=df.dropna()

# %%
df.dropna(subset=['Calories'], axis=0)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.fillna(value='555')
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 159        60    105       140     290.8
# 160        60    110       145     300.0
# 161        60    115       145     310.2
# 162        75    120       150     320.4
# 163        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df[df['Calories']==555]
# Out:
# Empty DataFrame
# Columns: [Duration, Pulse, Maxpulse, Calories]
# Index: []

# %%
df.shape
# Out:
# (164, 4)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# Length: 164, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 159        60    105       140     290.8
# 160        60    110       145     300.0
# 161        60    115       145     310.2
# 162        75    120       150     320.4
# 163        75    125       150     330.4
#
# [157 rows x 4 columns]

# %%
def times2(x):
    return x*2

# %%
df['Duration'].apply(times2).head()
# Out:
# 0    120
# 1    120
# 2    120
# 3     90
# 4     90
# Name: Duration, dtype: int64

# %%
df.shape
# Out:
# (164, 4)

# %%
com=df.groupby('Duration')
com.head()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 18         45     97       125     243.0
# 20         45    100       119     282.0
# 49         80    123       146     643.1
# 52         30    136       175     238.0
# 56         20    153       172     226.4
# 58        210    108       160    1376.0
# 59        160    110       137    1034.4
# 60        160    109       135     853.0
# 62         20    110       130     131.4
# 63        180     90       130     800.4
# 64        150    105       135     873.4
# 65        150    107       130     816.0
# 66         20    106       136     110.4
# ...

# %%
com=df.groupby('Duration')['Duration'].mean()
com.head()
# Out:
# Duration
# 15    15.0
# 20    20.0
# 25    25.0
# 30    30.0
# 45    45.0
# Name: Duration, dtype: float64
